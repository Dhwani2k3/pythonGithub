# %% [markdown]
# #### Ques 1)write a python script that prints your name ,Course name and the Python version you are using execute the command from the command line and include a screenshot of the output

# %%
print("Name : Dhwani Gupta")
print("Course : MCA - Master of Computer Application")
print("sap id :590015985")
import platform
print("Python Version : ",platform.python_version())
# Out:
# Name : Dhwani Gupta
# Course : MCA - Master of Computer Application
# sap id :590015985
# Python Version :  3.11.0

# %% [markdown]
# ![image.png](attachment:40e497e4-1330-454d-a9c2-262b7ce7e372.png)

# %% [markdown]
# ![image.png](attachment:adb3d0cc-7742-4ad7-a14f-1f6c465262b4.png)

# %% [markdown]
# #### Ques 2) Open idle and write a python script that print hello Python world save the script as hello.py and execute it using idle

# %%
print("Hello, Python World ! ")
# Out:
# Hello, Python World !

# %% [markdown]
# ![image.png](attachment:ab78a7c3-327b-4239-8408-79778c9a0328.png)

# %% [markdown]
# ![image.png](attachment:0e0eebff-14c0-4c72-971c-ba7c4c1f5d6c.png)

# %% [markdown]
# #### Ques 3) Write a Python program that takes a user's first and last name as input and prints them in reverse order with a space between them.

# %%
name=input("Enter your name : ")
sname=input("Enter your surname : ")
sn=name+" "+sname
print("Full Name : ",sn)
print("Name in Reverse Order : ",sn[-1::-1])
# Out:
# Enter your name :  Dhwani
# Enter your surname :  Gupta
# Full Name :  Dhwani Gupta
# Name in Reverse Order :  atpuG inawhD

# %% [markdown]
# #### Ques 4) Use at least two string methods and explain their purpose in the comments

# %%
xyz=input("enter any string : ")
# Out:
# enter any string :  hello , myself Dhwani

# %%
xyz.upper() # It convert all the alphabets into upper case and capitilize each of the alphabet
# Out:
# 'HELLO , MYSELF DHWANI'

# %%
xyz.lower() # It Convert all the alphabets in the cursive form and lower each of the alphabet
# Out:
# 'hello , myself dhwani'

# %%
xyz.capitalize() # It convert only the first alphabet of the string into upper case or capitallize it.
# Out:
# 'Hello , myself dhwani'

# %% [markdown]
# #### Ques 5) write a Python program that takes an input number from the user converts it to different numeric data type (integer, float and complex) and display the converted values

# %%
num=input("enter a number : ")

print("Float : ",float(num))    
print("Integer : ",int(num))
print("Complex : ",complex(num))
# Out:
# enter a number :  21
# Float :  21.0
# Integer :  21
# Complex :  (21+0j)

# %% [markdown]
# #### Ques 6) create a python script that calculate the area of a rectangle the script should prompt the user to enter the Length and width of the rectangle calculate the area display the result using the print function

# %%
# Area Of Rectangles 
length=float(input("Enter the length : "))
breadth=float(input("Enter the breadth : "))
area=length*breadth
print("The area of rectangle : ",int(area))
# Out:
# Enter the length :  21
# Enter the breadth :  21
# The area of rectangle :  441

# %% [markdown]
# #### Ques 7) modify the rectangle area program to format the output so that it displays the area with two decimal places

# %%
print("Area: {:.2f}".format(area))
# Out:
# Area: 441.00

# %% [markdown]
# #### Ques 8) write a python script that takes three numbers as input and print their average using the % method for sring formatting also use the print function to display a message that States the average of the three numbers is [calculated average]

# %%
#Average of three numbers
n1=int(input("enter first number : "))
n2=int(input("enter second number : "))
n3=int(input("enter third number : "))
sum=n1+n2+n3
average= sum / 3
print("The average of the three numbers is: %d"%(average))
print("The average of the three numbers is: ",average)
# Out:
# enter first number :  1
# enter second number :  5
# enter third number :  9
# The average of the three numbers is: 5
# The average of the three numbers is:  5.0

# %% [markdown]
# #### Ques 9) write a Python program that asks the user for a number and determine whether it is positive negative or zero implement a loop that continues to ask the user for a number until they entre exit use break to exit the loop and continue to prompt for a new number if the input is not exit.

# %%
#positive negative or zero
restart="yes"
while(restart=="yes" or restart=="Yes"):
    number=int(input("Enter a number : "))
    if (number==0):
        print("The number is Zero : ",number)
    elif (number>0):
        print("The number is Positive : ",number)
    else:
        print("The number is Negative : ",number)
    restart=input("Do You want to continue : ")
# Out:
# Enter a number :  25
# The number is Positive :  25
# Do You want to continue :  yes
# Enter a number :  51
# The number is Positive :  51
# Do You want to continue :  no

# %%
choice="yes"
while(True):
    if (choice=="yes"or restart=="Yes"):
        number=int(input("Enter a number : "))
    elif (choice=="exit"):
        break
    else:
        print("Invalid")
    choice=input("Do You want to continue : ")
# Out:
# Enter a number :  21
# Do You want to continue :  no
# Invalid
# Do You want to continue :  yes
# Enter a number :  51
# Do You want to continue :  exit

# %% [markdown]
# #### Ques 10) create a python script that takes two numbers as input and prints whether both numbers are even odd or one of each using relational and logical operators.

# %%
# Even or Odd Numbers
num1=int(input("Enter fisrt number : "))
num2=int(input("Enter second number : "))
print()
if (num1%2==0 and num2%2==0):
    print("Both Number are Even : ",num1,",",num2)
elif (num1%2!=0 and num2%2!=0):
    print("Both Number are Odd ",num1,",",num2)
elif (num1%2==0 or num2%2==0):
    if(num1%2==0):
        print("First Number is Even : ",num1,"\nSecond Number is Odd :",num2)
    elif(num2%2==0):
        print("First Number is Odd ",num1,"\nSecond Number is Even :",num2)
else:
    print("Invalid")
# Out:
# Enter fisrt number :  51
# Enter second number :  40
# First Number is Odd  51
# Second Number is Even : 40

# %% [markdown]
# #### Ques 11) write a Python program that takes an integer Input and print its binary octal and hexadecimal equivalent using a for loop and bitwise operators.

# %%
def convert_number(num):
    print(f"Decimal: {num}")
    
    # Binary
    print("Binary: ", end="")
    for i in range(31, -1, -1):
        print(1 if num & (1 << i) else 0, end="")
    print()
    
    # Octal
    print("Octal: {:o}".format(num))
    
    # Hexadecimal
    print("Hexadecimal: {:X}".format(num))

# Get user input
decimal_num = int(input("Enter a decimal number: "))

# Call the function to convert the number
convert_number(decimal_num)
# Out:
# Enter a decimal number:  15
# Decimal: 15
# Binary: 00000000000000000000000000001111
# Octal: 17
# Hexadecimal: F
